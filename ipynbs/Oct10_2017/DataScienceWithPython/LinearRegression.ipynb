# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 2, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# 0.20350905845934039

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='y')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
# %matplotlib inline
import numpy as np
from pylab import *
from scipy import stats
import matplotlib.pyplot as plt


def predict(x,slope,intercept):
    x2=[]
    y2=[]
    for i in len(x):
        x2.append(x[i]*1.0)
        y2.append(x2[i]*slope+intercept)
    print(x2)
    print(y2)
    return y2

x=[5,3,0,4]
y=[4,4,1,3]

theta0=0
theta1=1

def customRegFunc(t0,t1,x):
    y=[]
    for i in range(len(x)):
        y.append(x[i]*t1+t0)
    return y

yCustom = customRegFunc(theta0, theta1, x)

#Cost = yCustom - y
print(yCustom)
#print(Cost)    

#costfunction = 1/4*()

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(slope,intercept,r_value,p_value,std_err)

x2=[]
y2=[]
for i in range(len(x)):
    x2.append(x[i]*1.0)
    y2.append(x2[i]*slope+intercept)

#predict(x,slope,intercept)

#fitline = predict(x,slope,intercept)

plt.scatter(x, y)
plt.plot(x, y2, c='y')
plt.show()
# Out:
# [5, 3, 0, 4]
# 0.571428571429 1.28571428571 0.872871560944 0.127128439056 0.225876975726

# %%
NumC=[1,2,2,3,3,4,5,6,6,6,8,10]
EnRel=[-890,-1411,-1560,-2220,-2091,-2878,-3537,-3268,-3920,-4163,-5471,-5157]

slope, intercept, r_value, p_value, std_err = stats.linregress(NumC, EnRel)
print(slope,intercept,r_value,p_value,std_err)

def predict(x,y):
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    y=[]
    for i in range(len(x)):
        y.append(x[i]*slope+intercept)
    return y

fitLine = predict(NumC,EnRel)

plt.scatter(NumC, EnRel)
plt.plot(NumC, fitLine, c='y')
plt.show()
# Out:
# -530.906779661 -569.601694915 -0.965397131155 3.68636517945e-07 45.3516904416
